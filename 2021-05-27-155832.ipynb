# %%
plot(1/(x^2-4*x-5), (x, -5, -1.1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(1/(x^2-4*x-5), (x, -0.9, 4.9))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(1/(x^2-4*x-5), (x, 5.1, 10))
# Out:
# Graphics object consisting of 1 graphics primitive
